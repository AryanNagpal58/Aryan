# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy import units as u
from astropy import constants as const


df = pd.read_csv("../../course_assignments/homework9/solar_system.csv")

print(df.shape)
df = df.set_index("Attribute").T
df.index.name = "Planet"
df.reset_index(inplace = True)
df.columns.name = None

print(df.shape)
# Before the transposing, there are 20 rows and 11 columns. After transposing, there are 10 rows and 21 columns.

# The '.set_index("Attribute").T' command causes the column of "Attribute" to be turned into the new index column, as well as 
# transpose the data frame. This means that the rows of the original data frame become the columns of the new data frame, and the columns of the original data frame
# become the rows of the new data frame. By transposing the data frame, "Attribute" no longer becomes the index column, but more like an index row.

# The '.index.name' command creates a new label "Planet" above the names of the planets. This completes the index column for the planets since
# the label "Attributes" became the start of the index row for the attributes of each planet.

# The '.reset_index' command resets the data frame on a numerical index system, starting from 0 and going to 19. The "Attribute" label gets reset above the numerical index column, and the planet column stays in place.

# The command '.columns.name = None' gets rid of the column name "Attribute" entirely, and we are left with the transposes data frame where the planets are numerically indexed, and the following columns show their attributes.

# The new shape is (10, 21) and not (11, 20) because what would have been the row for planet names became a column during the transpose. Instead of being a data frame structured with numerical index with 

print(df.columns)
# 16 of the 21 columns have units. In order, these are mass (10^24 kg's), diameter (km), density (kg/m^3), gravity (m/s^2), 

# 5 of the 21 columns have units. In order, these are 

print(df)
# Out:
# (20, 11)
# (10, 21)
# Index(['Planet', 'Mass (10^24kg)', 'Diameter (km)', 'Density (kg/m^3)',
#        'Gravity (m/s^2)', 'Escape Velocity (km/s)', 'Rotation Period (hours)',
#        'Length of Day (hours)', 'Distance from Sun (10^6 km)',
#        'Perihelion (10^6 km)', 'Aphelion (10^6 km)', 'Orbital Period (days)',
#        'Orbital Velocity (km/s)', 'Orbital Inclination (deg)',
#        'Orbital Eccentricity', 'Obliquity to Orbit (deg)',
#        'Mean Temperature (C)', 'Surface Pressure (bars)', 'Number of Moons',
#        'Ring System?', 'Global Magnetic Field?'],
#       dtype='object')
#     Planet Mass (10^24kg) Diameter (km) Density (kg/m^3) Gravity (m/s^2)  \
# 0  Mercury          0.330          4879             5429             3.7
# 1    Venus           4.87         12104             5243             8.9
# 2    Earth           5.97         12756             5514             9.8
# 3     Moon          0.073          3475             3340             1.6
# ...

# %%
# 2.12 Investigate Data Types

print(df.dtypes)

for col in df:
    print(df[col].apply(type))

# 3. 
# a). All of the actual values are of the string class
# b). Storing numeric values as strings is a problem for data analysis because the computer will read the values as strings,
#     causing errors when trying to analyze the numeric meaning for the values, or when doing math with them.

# 2.1.3 Convert Strings to Numbers

skip_col = ["Planet", "Ring System?", "Global Magnetic Field?"]


for col in df.columns:
    if col in skip_col:
        continue
    df[col] = pd.to_numeric(df[col], errors = "coerce")

print(df.dtypes)

# What are the three different data types now in the Data Frame?
# The three different types currently being use are object, float64 and int64

# Define each one:
# The object type is
# The float64 type is
# The int64 type is

# The columns that are still object are "Planet", "Ring System?", and "Global Magnetic Field?" because they were made to skip the change to numeric values.

def attach_units():
# Out:
# Planet                         object
# Mass (10^24kg)                 object
# Diameter (km)                  object
# Density (kg/m^3)               object
# Gravity (m/s^2)                object
# Escape Velocity (km/s)         object
# Rotation Period (hours)        object
# Length of Day (hours)          object
# Distance from Sun (10^6 km)    object
# Perihelion (10^6 km)           object
# Aphelion (10^6 km)             object
# Orbital Period (days)          object
# Orbital Velocity (km/s)        object
# Orbital Inclination (deg)      object
# Orbital Eccentricity           object
# Obliquity to Orbit (deg)       object
# Mean Temperature (C)           object
# Surface Pressure (bars)        object
# Number of Moons                object
# Ring System?                   object
# Global Magnetic Field?         object
# dtype: object
# 0    <class 'str'>
# 1    <class 'str'>
# 2    <class 'str'>
# 3    <class 'str'>
# 4    <class 'str'>
# 5    <class 'str'>
# ...
